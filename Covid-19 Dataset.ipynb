# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')

# %%
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv'

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#     Province/State  Country/Region      Lat  ...  3/16/20  3/17/20  3/18/20
# 0              NaN        Thailand  15.0000  ...      147      177      212
# 1              NaN           Japan  36.0000  ...      825      878      889
# 2              NaN       Singapore   1.2833  ...      243      266      313
# 3              NaN           Nepal  28.1667  ...        1        1        1
# 4              NaN        Malaysia   2.5000  ...      566      673      790
# ..             ...             ...      ...  ...      ...      ...      ...
# 457          Aruba     Netherlands  12.5186  ...        2        3        4
# 458            NaN          Zambia -15.4167  ...        0        0        2
# 459            NaN        Djibouti  11.8251  ...        0        0        1
# 460            NaN     Gambia, The  13.4432  ...        0        1        1
# 461     Montserrat  United Kingdom  16.7425  ...        0        0        1
#
# [462 rows x 61 columns]

# %%
df.transpose()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-e61a5c7c2534> in <module>()
# ----> 1 df.transpose(inplace=True)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in transpose(self, *args, **kwargs)
#    2769         """
#    2770         nv.validate_transpose(args, dict())
# -> 2771         return super().transpose(1, 0, **kwargs)
#    2772
#    2773     T = property(transpose)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in transpose(self, *args, **kwargs)
#     732             new_values = new_values.copy()
#     733
# --> 734         nv.validate_transpose(tuple(), kwargs)
#     735         return self._constructor(new_values, **new_axes).__finalize__(self)
#     736
#
# /usr/local/lib/python3.6/dist-packages/pandas/compat/numpy/function.py in __call__(self, args, kwargs, fname, max_fname_arg_count, method)
#      56             elif method == "both":
#      57                 validate_args_and_kwargs(
# ---> 58                     fname, args, kwargs, max_fname_arg_count, self.defaults
#      59                 )
#      60             else:
#
# /usr/local/lib/python3.6/dist-packages/pandas/util/_validators.py in validate_args_and_kwargs(fname, args, kwargs, max_fname_arg_count, compat_args)
#     226
#     227     kwargs.update(args_dict)
# --> 228     validate_kwargs(fname, kwargs, compat_args)
#     229
#     230
#
# /usr/local/lib/python3.6/dist-packages/pandas/util/_validators.py in validate_kwargs(fname, kwargs, compat_args)
#     163     """
#     164     kwds = kwargs.copy()
# --> 165     _check_for_invalid_keys(fname, kwargs, compat_args)
#     166     _check_for_default_values(fname, kwds, compat_args)
#     167
#
# /usr/local/lib/python3.6/dist-packages/pandas/util/_validators.py in _check_for_invalid_keys(fname, kwargs, compat_args)
#     132             (
#     133                 "{fname}() got an unexpected "
# --> 134                 "keyword argument '{arg}'".format(fname=fname, arg=bad_arg)
#     135             )
#     136         )
#
# TypeError: transpose() got an unexpected keyword argument 'inplace'

# %%
x =
# Out:
#     Province/State  Country/Region      Lat  ...  3/16/20  3/17/20  3/18/20
# 0              NaN        Thailand  15.0000  ...      147      177      212
# 1              NaN           Japan  36.0000  ...      825      878      889
# 2              NaN       Singapore   1.2833  ...      243      266      313
# 3              NaN           Nepal  28.1667  ...        1        1        1
# 4              NaN        Malaysia   2.5000  ...      566      673      790
# ..             ...             ...      ...  ...      ...      ...      ...
# 457          Aruba     Netherlands  12.5186  ...        2        3        4
# 458            NaN          Zambia -15.4167  ...        0        0        2
# 459            NaN        Djibouti  11.8251  ...        0        0        1
# 460            NaN     Gambia, The  13.4432  ...        0        1        1
# 461     Montserrat  United Kingdom  16.7425  ...        0        0        1
#
# [462 rows x 61 columns]
